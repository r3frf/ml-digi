# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.formula.api import ols
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
import plotly.express as px
from sklearn.compose import TransformedTargetRegressor

# %%
df=pd.read_csv("Marriage_Divorce_DB - Marriage_Divorce_DB.csv")
df.columns
# Out:
# Index(['Age_Gap', 'Education', 'Economic_Similarity', 'Social_Similarities',
#        'Cultural_Similarities', 'Social_Gap', 'Common_Interests',
#        'Religion_Compatibility', 'No_of_Children_from_Previous_Marriage',
#        'Desire_to_Marry', 'Independency',
#        'Relationship_with_the_Spouse_Family', 'Trading_in', 'Engagement_Time',
#        'Love', 'Commitment', 'Mental_Health', 'Having_Children',
#        'Previous_Trading', 'Previous_Marriage', 'The_Proportion', 'Addiction',
#        'Loyalty', 'Height_Ratio', 'Good_Income', 'Self_Confidence',
#        'RelationMarriage', 'SpouFamily', 'Divorce_in_the_FamilyGrade',
#        'Start_Socializingwithsit', 'Divorce_Probability'],
#       dtype='object')

# %%
X=df[['Age_Gap', 'Education', 'Economic_Similarity', 'Social_Similarities',
       'Cultural_Similarities', 'Social_Gap', 'Common_Interests',
       'Religion_Compatibility', 'No_of_Children_from_Previous_Marriage',
       'Desire_to_Marry', 'Independency',
       'Relationship_with_the_Spouse_Family', 'Trading_in', 'Engagement_Time',
       'Love', 'Commitment', 'Mental_Health', 'Having_Children',
       'Previous_Trading', 'Previous_Marriage', 'The_Proportion', 'Addiction',
       'Loyalty', 'Height_Ratio', 'Good_Income', 'Self_Confidence',
       'RelationMarriage', 'SpouFamily', 'Divorce_in_the_FamilyGrade',
       'Start_Socializingwithsit']]
Y=df["Divorce_Probability"]
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,random_state=0,test_size=.25)

# %%
# select model
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier()

# %%
S1=RandomForestClassifier()

# %%
S1.fit(xtrain,ytrain)
y_pre=S1.predict(xtest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Lenovo\ml digi\div.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/ml%20digi/div.ipynb#ch0000007?line=0'>1</a> S1.fit(xtrain,ytrain)
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/ml%20digi/div.ipynb#ch0000007?line=1'>2</a> y_pre=S1.predict(xtest)
#
# File c:\Users\Lenovo\.conda\envs\ml\lib\site-packages\sklearn\ensemble\_forest.py:371, in BaseForest.fit(self, X, y, sample_weight)
#     364         raise ValueError(
#     365             "Sum of y is not strictly positive which "
#     366             "is necessary for Poisson regression."
#     367         )
#     369 self.n_outputs_ = y.shape[1]
# --> 371 y, expanded_class_weight = self._validate_y_class_weight(y)
#     373 if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
# ...

# %%
r2_score(y_true=ytest,y_pred=y_pre)
# Out:
# -0.014784492971069652

# %%
plt.scatter(ytest,y_pre)

A=df.columns

# %%
for i in A:
    print(ols(f"Divorce_Probability~{i}",data=df).fit().summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Divorce_Probability   R-squared:                       0.009
# Model:                             OLS   Adj. R-squared:                 -0.001
# Method:                  Least Squares   F-statistic:                    0.9318
# Date:                 Wed, 24 Aug 2022   Prob (F-statistic):              0.337
# Time:                         01:11:03   Log-Likelihood:                -83.466
# No. Observations:                  100   AIC:                             170.9
# Df Residuals:                       98   BIC:                             176.1
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9600      0.125     15.737      0.000       1.713       2.207
# ...
