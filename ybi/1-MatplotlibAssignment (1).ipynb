# %% [markdown]
# # **⭐ Matplotlib Assignment**

# %% [markdown]
# # **🔥 Note: Solve this Assignment and Save it as Pdf. Rename Pdf as your registered email id before final submission.**

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create blank figure
fig , ax= plt.subplots()

# %%
# create blank figure with 3 rows and 1 column subplots

# %%
# create blank figure with 3 rows and 2 column subplots

# %%
# change the figure size of above to (10,15)

# %%
# import Tips data from YBI Foundation Github page
tip = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Tips.csv')

# %%
# view first 5 line
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# view info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
# creat a scatter plot of total bill and tip

# %%
# creat a bar plot of total bill and day

# %%
# creat a horizontal bar plot of tip and day

# %%
# creat a line chart of tip and total bill

# %%
# creat a line chart of tip paid for each row index

# %%
# create a pie chart of size

# %%
# create a histogram of tip
